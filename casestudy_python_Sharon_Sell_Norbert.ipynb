# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharonsellnorbert/DSA_B13_casestudy/blob/main/casestudy_python_Sharon_Sell_Norbert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
id=int(input("Enter Employee ID:"))
employees = [
    {"id":101, "name":"Alice", "department":"Data", "salary":65000, "rating":4.5},
    {"id":102, "name":"Bob", "department":"AI", "salary":72000, "rating":4.8},
    {"id":103, "name":"Charlie", "department":"Web", "salary":58000, "rating":3.9},
    {"id":104, "name":"David", "department":"Data", "salary":61000, "rating":4.2},
    {"id":105, "name":"Eva", "department":"AI", "salary":75000, "rating":4.9},
    {"id":106, "name":"Frank", "department":"Cloud", "salary":68000, "rating":4.1},
    {"id":107, "name":"Grace", "department":"Web", "salary":59000, "rating":3.8},
    {"id":108, "name":"Helen", "department":"Data", "salary":70000, "rating":4.6}
]

avg=0
highest=0
lowest=employees[0]["salary"]
total=0
new={}
num=len(employees)
nlist=[]
ntuple=()
flag=0

for i in employees:
  if i["id"]==id:
    flag=1


if flag==1:
  print("Total Number of Employees:",num)





  print("\n")
  for i in employees:
    if i["salary"]<lowest:
     lowest=i["salary"]

  for i in employees:
    total=total+i["salary"]
    if i["salary"]>highest:
      highest=i["salary"]

  print("Average Salary:",total/num)
  print("Highest Salary:",highest)
  print("Lowest Salary:",lowest)
  print("\n")



  print("Employees with Salary > 65000 and Rating >= 4.5")
  for i in employees:
    if i["salary"]>65000 and i["rating"]>=4.5:
     print(i["name"])



  print("\n")
  for i in employees:
    new[i["id"]]=i["name"]
  print("Employee Dictionary")
  print(new)




  print("\n")
  for i in employees:
    nlist.append(i["name"])
  nlist.sort()
  nlist.sort(reverse=True)
  print("\nFirst Three Employee Names")
  for i in range(3):
    print(nlist[i])



  print("\n")
  for i in employees:
    ntuple+=(i["id"],)

  print("\nEmployee ID Tuple")
  print(ntuple)



  print("\n")
  print("Maximum Employee ID",max(ntuple))
  print("Maximum Employee ID",min(ntuple))



  print("\n")
  dept={employees[0]["department"]}
  for i in employees:
    if i["department"] not in dept:
      dept.add(i["department"])
  print("Departments")
  print(dept)



  print("\n")
  print("Employee Found")
  print("ID:",i["id"])
  print("Name:",i["name"])
  print("Department:",i["department"])
  print("Salary:",i["salary"])
  print("Rating:",i["rating"])
else:
  print("\nEmployee Not Found")
# Out:
# Enter Employee ID:120
#
# Employee Not Found
